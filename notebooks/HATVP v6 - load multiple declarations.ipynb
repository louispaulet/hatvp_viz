# %%
# !pip install flatten_dict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flatten_dict in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: six<2.0,>=1.12 in /usr/local/lib/python3.10/dist-packages (from flatten_dict) (1.16.0)

# %%
import requests
import xml.etree.ElementTree as ET
import pandas as pd
from flatten_dict import flatten

def parse_xml(url):
    response = requests.get(url)
    data = response.text
    
    # Parse XML into ElementTree object
    root = ET.fromstring(data)
    
    # Convert ElementTree object into nested dictionary
    xml_dict = element_to_dict(root)
    
    # Flatten the nested dictionary
    flat_dict = flatten(xml_dict, reducer='underscore')
    
    df = pd.DataFrame.from_dict(flat_dict, orient='index').transpose()
    return df


def parse_xml_from_text(input_text):   
    # Flatten the nested dictionary
    flat_dict = flatten(input_text, reducer='underscore')
    
    df = pd.DataFrame.from_dict(flat_dict, orient='index').transpose()
    return df

# Helper function to convert ElementTree object to nested dictionary
def element_to_dict(element):
    result = {}
    
    # Store tag name as key
    result[element.tag] = {}
    
    # Store attributes as sub-dictionary if present
    if element.attrib:
        result[element.tag]['attributes'] = element.attrib
    
    # Store text content if present
    if element.text and element.text.strip():
        result[element.tag]['text'] = element.text.strip()
    
    # Process child elements recursively
    for child in element:
        child_dict = element_to_dict(child)
        if child.tag in result[element.tag]:
            # Handle multiple elements with the same tag name
            if isinstance(result[element.tag][child.tag], list):
                result[element.tag][child.tag].append(child_dict[child.tag])
            else:
                result[element.tag][child.tag] = [result[element.tag][child.tag], child_dict[child.tag]]
        else:
            result[element.tag].update(child_dict)
    
    return result

url = "https://raw.githubusercontent.com/louispaulet/hatvp_viz/main/datasets/base/xml_batches/declarations_hatvp_batch_1.xml"
df = parse_xml(url)
df
# Out:
#                              declarations_declaration
# 0   {'dateDepot': {'text': '11/07/2022 15:40:13'},...
# 1   {'dateDepot': {'text': '27/11/2022 18:18:23'},...
# 2   {'dateDepot': {'text': '19/08/2022 10:08:23'},...
# 3   {'dateDepot': {'text': '04/10/2022 17:22:07'},...
# 4   {'dateDepot': {'text': '03/09/2021 10:41:48'},...
# ..                                                ...
# 95  {'dateDepot': {'text': '30/07/2021 10:49:14'},...
# 96  {'dateDepot': {'text': '26/04/2022 15:22:12'},...
# 97  {'dateDepot': {'text': '23/03/2021 10:55:37'},...
# 98  {'dateDepot': {'text': '10/09/2020 12:31:53'},...
# 99  {'dateDepot': {'text': '20/09/2021 22:53:49'},...
#
# [100 rows x 1 columns]

# %%
def explode_and_concat(df, column):
    # Create a temporary DataFrame that contains the column to be exploded along with the other columns in the original DataFrame
    temp_df = df.copy()
    
    # Explode the column containing lists
    temp_df = temp_df.explode(column)
    
    
    # Normalize the DataFrame
    df_to_normalize = pd.json_normalize(temp_df[column])
    df_to_normalize = df_to_normalize.add_prefix(column + '_')
    
    # Merge the original DataFrame with the normalized DataFrame
    result = pd.concat([temp_df.reset_index(drop=True), df_to_normalize.reset_index(drop=True)], axis=1)
    
    # Drop the original column as its content has been normalized and added as new columns
    result = result.drop(columns=[column])
    
    return result

def not_explode_and_concat(df, column):
    # Create a temporary DataFrame that contains the column to be exploded along with the other columns in the original DataFrame
    temp_df = df.copy()
    
    # Explode the column containing lists
    # temp_df = temp_df.explode(column)
    
    
    # Normalize the DataFrame
    df_to_normalize = pd.json_normalize(temp_df[column])
    df_to_normalize = df_to_normalize.add_prefix(column + '_')
    
    # Merge the original DataFrame with the normalized DataFrame
    result = pd.concat([temp_df.reset_index(drop=True), df_to_normalize.reset_index(drop=True)], axis=1)
    
    # Drop the original column as its content has been normalized and added as new columns
    result = result.drop(columns=[column])
    
    return result

# %%
columns_to_explode = [
    # 'declaration_mandatElectifDto_items_items',
    # 'declaration_mandatElectifDto_items_items_remuneration.montant.montant',
    # 'declaration_participationDirigeantDto_items_items',
    'declarations_declaration',
    # 'declaration_participationFinanciereDto_items_items',
    # 'declaration_activCollaborateursDto_items_items',
    # 'declaration_participationDirigeantDto_items_items_remuneration.montant.montant'
]

exploded_df = df

for column in columns_to_explode:
    exploded_df = not_explode_and_concat(exploded_df, column)

# %%
exploded_df["declarations_declaration_participationFinanciereDto.items.items"]
# Out:
# 0     [{'motif': {'id': {'text': 'CREATION'}, 'label...
# 1     [{'motif': {'id': {'text': 'CREATION'}, 'label...
# 2     [{'motif': {'id': {'text': 'CREATION'}, 'label...
# 3     [{'motif': {'id': {'text': 'CREATION'}, 'label...
# 4                                                   NaN
#                             ...
# 95                                                  NaN
# 96                                                  NaN
# 97    [{'motif': {'id': {'text': 'CREATION'}, 'label...
# 98                                                  NaN
# 99                                                  NaN
# Name: declarations_declaration_participationFinanciereDto.items.items, Length: 100, dtype: object

# %%
exploded_df.head(1).T
# Out:
#                                                                                        0
# declarations_declaration_dateDepot.text                              11/07/2022 15:40:13
# declarations_declaration_uuid.text                  4344aaa1-874d-4e6d-9b1a-45f7725b710c
# declarations_declaration_origine.text                                               ADEL
# declarations_declaration_complete.text                                              true
# declarations_declaration_attachedFiles.attached...     VUE_PDF_DU_RECEPISSE_DU_DEPOT_XML
# ...                                                                                  ...
# declarations_declaration_fonctionBenevoleDto.it...                                   NaN
# declarations_declaration_mandatElectifDto.items...                                   NaN
# declarations_declaration_mandatElectifDto.items...                                   NaN
# declarations_declaration_participationDirigeant...                                   NaN
# declarations_declaration_activConsultantDto.ite...                                   NaN
#
# [165 rows x 1 columns]

# %%
exploded_df = exploded_df[["declarations_declaration_uuid.text",
"declarations_declaration_dateDepot.text",
"declarations_declaration_general.declarant.nom.text",
"declarations_declaration_general.declarant.prenom.text",
"declarations_declaration_general.declarant.dateNaissance.text",
"declarations_declaration_general.qualiteDeclarantForPDF.text",
"declarations_declaration_participationFinanciereDto.items.items"]]

# %%
columns_to_explode = [
    # 'declaration_mandatElectifDto_items_items',
    # 'declaration_mandatElectifDto_items_items_remuneration.montant.montant',
    # 'declaration_participationDirigeantDto_items_items',
    # 'declarations_declaration',
    # 'declaration_participationFinanciereDto_items_items',
    # 'declaration_activCollaborateursDto_items_items',
    # 'declaration_participationDirigeantDto_items_items_remuneration.montant.montant'

    "declarations_declaration_participationFinanciereDto.items.items"
]

for column in columns_to_explode:
    exploded_df = explode_and_concat(exploded_df, column)

# %%
exploded_df
# Out:
#        declarations_declaration_uuid.text  \
# 0    4344aaa1-874d-4e6d-9b1a-45f7725b710c
# 1    4344aaa1-874d-4e6d-9b1a-45f7725b710c
# 2    4344aaa1-874d-4e6d-9b1a-45f7725b710c
# 3    4344aaa1-874d-4e6d-9b1a-45f7725b710c
# 4    fa8d18ec-0db9-4a39-b1f4-caba0c31329b
# ..                                    ...
# 169  29354efc-115c-4505-930a-8e4f4d620f85
# 170  29354efc-115c-4505-930a-8e4f4d620f85
# 171  29354efc-115c-4505-930a-8e4f4d620f85
# 172  86dd9c5d-41ec-44aa-b664-f8d8ba099348
# 173  c4221cda-18e7-4ee2-96a5-2bbfa7b584e9
#
#     declarations_declaration_dateDepot.text  \
# 0                       11/07/2022 15:40:13
# 1                       11/07/2022 15:40:13
# 2                       11/07/2022 15:40:13
# 3                       11/07/2022 15:40:13
# 4                       27/11/2022 18:18:23
# ..                                      ...
# 169                     23/03/2021 10:55:37
# 170                     23/03/2021 10:55:37
# 171                     23/03/2021 10:55:37
# 172                     10/09/2020 12:31:53
# 173                     20/09/2021 22:53:49
#
#     declarations_declaration_general.declarant.nom.text  \
# 0                                                 ABAD
# 1                                                 ABAD
# 2                                                 ABAD
# 3                                                 ABAD
# 4                                                 ABAD
# ..                                                 ...
# 169                                              ALEDO
# 170                                              ALEDO
# 171                                              ALEDO
# 172                                           ALEMAGNA
# 173                                           ALEMAGNA
#
#     declarations_declaration_general.declarant.prenom.text  \
# 0                                               DAMIEN
# 1                                               DAMIEN
# 2                                               DAMIEN
# 3                                               DAMIEN
# 4                                               DAMIEN
# ..                                                 ...
# 169                                             Marcel
# 170                                             Marcel
# 171                                             Marcel
# 172                                             Claude
# 173                                             Claude
#
#     declarations_declaration_general.declarant.dateNaissance.text  \
# 0                                           05/04/1980
# 1                                           05/04/1980
# 2                                           05/04/1980
# 3                                           05/04/1980
# 4                                           05/04/1980
# ..                                                 ...
# 169                                         11/07/1948
# 170                                         11/07/1948
# 171                                         11/07/1948
# 172                                         21/09/1957
# 173                                         21/09/1957
#
#     declarations_declaration_general.qualiteDeclarantForPDF.text  \
# 0                                       Député/Ain(01)
# 1                                       Député/Ain(01)
# 2                                       Député/Ain(01)
# 3                                       Député/Ain(01)
# 4                                       Député/Ain(01)
# ..                                                 ...
# 169   Maire ou adjoint municipal/Clermont-Ferrand (63)
# 170   Maire ou adjoint municipal/Clermont-Ferrand (63)
# 171   Maire ou adjoint municipal/Clermont-Ferrand (63)
# 172  Membre d’EPCI/Dracénie Provence Verdon agglomé...
# 173  Membre d’EPCI/Dracénie Provence Verdon agglomé...
#
#     declarations_declaration_participationFinanciereDto.items.items_motif.id.text  \
# 0                                             CREATION
# 1                                             CREATION
# 2                                             CREATION
# 3                                             CREATION
# 4                                             CREATION
# ..                                                 ...
# 169                                           CREATION
# 170                                           CREATION
# 171                                           CREATION
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_commentaire.text  \
# 0                               [Données non publiées]
# 1                               [Données non publiées]
# 2                               [Données non publiées]
# 3                               [Données non publiées]
# 4                               [Données non publiées]
# ..                                                 ...
# 169                           Titre détenu en usufruit
# 170                           Titre détenu en usufruit
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_nomSociete.text  \
# 0                                               ORANGE
# 1                                   CREDIT AGRICOLE SA
# 2                                               AIRBUS
# 3                                              L'OREAL
# 4                                               ORANGE
# ..                                                 ...
# 169                SCI\n        [Données non publiées]
# 170                SCI\n        [Données non publiées]
# 171                SCI\n        [Données non publiées]
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_evaluation.text  \
# 0                                                  877
# 1                                                 2910
# 2                                                 1929
# 3                                                 6552
# 4                                                  877
# ..                                                 ...
# 169                                              33027
# 170                                                  0
# 171                                                  0
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_remuneration.text  \
# 0                                                néant
# 1                                                néant
# 2                                                NEANT
# 3                                                NEANT
# 4                                                néant
# ..                                                 ...
# 169                                              Néant
# 170                                              Néant
# 171                                              Néant
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_nombreParts.text  \
# 0                                                   83
# 1                                                  341
# 2                                                   20
# 3                                                   20
# 4                                                   83
# ..                                                 ...
# 169                                               1500
# 170                                                 99
# 171                                               5200
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_actiConseil.text  \
# 0                                                  Non
# 1                                                  Non
# 2                                                  Non
# 3                                                  Non
# 4                                                  Non
# ..                                                 ...
# 169                                                NaN
# 170                                                NaN
# 171                                                NaN
# 172                                                NaN
# 173                                                NaN
#
#     declarations_declaration_participationFinanciereDto.items.items_capitalDetenu.text
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 169                                                 81
# 170                                                100
# 171                                                 81
# 172                                                NaN
# 173                                                NaN
#
# [174 rows x 14 columns]

# %%
exploded_df.to_csv('first_small_finance_extract.csv')

# %%
exploded_df.describe()
# Out:
#           declarations_declaration_uuid.text  \
# count                                    174
# unique                                    98
# top     4794faad-da62-40f8-a76d-8e05539adeb8
# freq                                      22
#
#        declarations_declaration_dateDepot.text  \
# count                                      174
# unique                                      98
# top                        02/02/2022 22:05:45
# freq                                        22
#
#        declarations_declaration_general.declarant.nom.text  \
# count                                                 174
# unique                                                 53
# top                                                 ALAIN
# freq                                                   28
#
#        declarations_declaration_general.declarant.prenom.text  \
# count                                                 174
# unique                                                 54
# top                                               Valérie
# freq                                                   28
#
#        declarations_declaration_general.declarant.dateNaissance.text  \
# count                                                 174
# unique                                                 55
# top                                            28/02/1961
# freq                                                   28
#
#        declarations_declaration_general.qualiteDeclarantForPDF.text  \
# count                                                 169
# unique                                                 78
# top     Elu départemental/Orne (61)/Vice-président en ...
# freq                                                   22
#
#        declarations_declaration_participationFinanciereDto.items.items_motif.id.text  \
# count                                                  94
# unique                                                  1
# top                                              CREATION
# freq                                                   94
#
#        declarations_declaration_participationFinanciereDto.items.items_commentaire.text  \
# count                                                  59
# unique                                                 23
# top             Donation \n        [Données non publiées]
# freq                                                   12
#
#        declarations_declaration_participationFinanciereDto.items.items_nomSociete.text  \
# count                                                  94
# unique                                                 46
# top                  SCI \n        [Données non publiées]
# freq                                                   15
#
#        declarations_declaration_participationFinanciereDto.items.items_evaluation.text  \
# count                                                  94
# unique                                                 71
# top                                                   500
# freq                                                    7
#
#        declarations_declaration_participationFinanciereDto.items.items_remuneration.text  \
# count                                                  94
# unique                                                 27
# top                                                 Néant
# freq                                                   22
#
#        declarations_declaration_participationFinanciereDto.items.items_nombreParts.text  \
# count                                                  94
# unique                                                 48
# top                                                   100
# freq                                                   16
#
#        declarations_declaration_participationFinanciereDto.items.items_actiConseil.text  \
# count                                                  34
# unique                                                  1
# top                                                   Non
# freq                                                   34
#
#        declarations_declaration_participationFinanciereDto.items.items_capitalDetenu.text
# count                                                  49
# unique                                                 18
# top                                                     0
# freq                                                    6

# %%
import pandas as pd

strings_to_remove = [
    'declarations_declaration_general.',
    'declarations_declaration_participationFinanciereDto.items.items_',
    '.text'
]

# Assuming you have a dataframe named 'exploded_df'

# Create a new list to store the modified column names
modified_columns = []

# Iterate over each column name
for col in exploded_df.columns:
    modified_col = col
    # Iterate over each string to remove
    for string in strings_to_remove:
        modified_col = modified_col.replace(string, '')

    modified_col = modified_col.replace('.', '_')
    # Add the modified column name to the list
    modified_columns.append(modified_col)

# Assign the modified column names back to the dataframe
exploded_df.columns = modified_columns

# %%
exploded_df
# Out:
#             declarations_declaration_uuid declarations_declaration_dateDepot  \
# 0    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 1    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 2    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 3    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 4    fa8d18ec-0db9-4a39-b1f4-caba0c31329b                27/11/2022 18:18:23
# ..                                    ...                                ...
# 169  29354efc-115c-4505-930a-8e4f4d620f85                23/03/2021 10:55:37
# 170  29354efc-115c-4505-930a-8e4f4d620f85                23/03/2021 10:55:37
# 171  29354efc-115c-4505-930a-8e4f4d620f85                23/03/2021 10:55:37
# 172  86dd9c5d-41ec-44aa-b664-f8d8ba099348                10/09/2020 12:31:53
# 173  c4221cda-18e7-4ee2-96a5-2bbfa7b584e9                20/09/2021 22:53:49
#
#     declarant_nom declarant_prenom declarant_dateNaissance  \
# 0            ABAD           DAMIEN              05/04/1980
# 1            ABAD           DAMIEN              05/04/1980
# 2            ABAD           DAMIEN              05/04/1980
# 3            ABAD           DAMIEN              05/04/1980
# 4            ABAD           DAMIEN              05/04/1980
# ..            ...              ...                     ...
# 169         ALEDO           Marcel              11/07/1948
# 170         ALEDO           Marcel              11/07/1948
# 171         ALEDO           Marcel              11/07/1948
# 172      ALEMAGNA           Claude              21/09/1957
# 173      ALEMAGNA           Claude              21/09/1957
#
#                                 qualiteDeclarantForPDF  motif_id  \
# 0                                       Député/Ain(01)  CREATION
# 1                                       Député/Ain(01)  CREATION
# 2                                       Député/Ain(01)  CREATION
# 3                                       Député/Ain(01)  CREATION
# 4                                       Député/Ain(01)  CREATION
# ..                                                 ...       ...
# 169   Maire ou adjoint municipal/Clermont-Ferrand (63)  CREATION
# 170   Maire ou adjoint municipal/Clermont-Ferrand (63)  CREATION
# 171   Maire ou adjoint municipal/Clermont-Ferrand (63)  CREATION
# 172  Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
# 173  Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
#
#                   commentaire                           nomSociete evaluation  \
# 0      [Données non publiées]                               ORANGE        877
# 1      [Données non publiées]                   CREDIT AGRICOLE SA       2910
# 2      [Données non publiées]                               AIRBUS       1929
# 3      [Données non publiées]                              L'OREAL       6552
# 4      [Données non publiées]                               ORANGE        877
# ..                        ...                                  ...        ...
# 169  Titre détenu en usufruit  SCI\n        [Données non publiées]      33027
# 170  Titre détenu en usufruit  SCI\n        [Données non publiées]          0
# 171                       NaN  SCI\n        [Données non publiées]          0
# 172                       NaN                                  NaN        NaN
# 173                       NaN                                  NaN        NaN
#
#     remuneration nombreParts actiConseil capitalDetenu
# 0          néant          83         Non           NaN
# 1          néant         341         Non           NaN
# 2          NEANT          20         Non           NaN
# 3          NEANT          20         Non           NaN
# 4          néant          83         Non           NaN
# ..           ...         ...         ...           ...
# 169        Néant        1500         NaN            81
# 170        Néant          99         NaN           100
# 171        Néant        5200         NaN            81
# 172          NaN         NaN         NaN           NaN
# 173          NaN         NaN         NaN           NaN
#
# [174 rows x 14 columns]

# %% [markdown]
# ## ultra complete package

# %%
def get_stocks_for_url(url):
  df = parse_xml(url)
  df
  columns_to_explode = [
      'declarations_declaration',
  ]

  exploded_df = df

  for column in columns_to_explode:
      exploded_df = not_explode_and_concat(exploded_df, column)

  exploded_df = exploded_df[["declarations_declaration_uuid.text",
  "declarations_declaration_dateDepot.text",
  "declarations_declaration_general.declarant.nom.text",
  "declarations_declaration_general.declarant.prenom.text",
  "declarations_declaration_general.declarant.dateNaissance.text",
  "declarations_declaration_general.qualiteDeclarantForPDF.text",
  "declarations_declaration_participationFinanciereDto.items.items"]]
  columns_to_explode = [
      "declarations_declaration_participationFinanciereDto.items.items"
  ]

  for column in columns_to_explode:
      exploded_df = explode_and_concat(exploded_df, column)
  strings_to_remove = [
      'declarations_declaration_general.',
      'declarations_declaration_participationFinanciereDto.items.items_',
      '.text'
  ]

  # Assuming you have a dataframe named 'exploded_df'

  # Create a new list to store the modified column names
  modified_columns = []

  # Iterate over each column name
  for col in exploded_df.columns:
      modified_col = col
      # Iterate over each string to remove
      for string in strings_to_remove:
          modified_col = modified_col.replace(string, '')

      modified_col = modified_col.replace('.', '_')
      # Add the modified column name to the list
      modified_columns.append(modified_col)

  # Assign the modified column names back to the dataframe
  exploded_df.columns = modified_columns

  return exploded_df

# %%
url = "https://raw.githubusercontent.com/louispaulet/hatvp_viz/main/datasets/base/xml_batches/declarations_hatvp_batch_1.xml"
get_stocks_for_url(url)
# Out:
#             declarations_declaration_uuid declarations_declaration_dateDepot  \
# 0    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 1    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 2    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 3    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 4    fa8d18ec-0db9-4a39-b1f4-caba0c31329b                27/11/2022 18:18:23
# ..                                    ...                                ...
# 169  29354efc-115c-4505-930a-8e4f4d620f85                23/03/2021 10:55:37
# 170  29354efc-115c-4505-930a-8e4f4d620f85                23/03/2021 10:55:37
# 171  29354efc-115c-4505-930a-8e4f4d620f85                23/03/2021 10:55:37
# 172  86dd9c5d-41ec-44aa-b664-f8d8ba099348                10/09/2020 12:31:53
# 173  c4221cda-18e7-4ee2-96a5-2bbfa7b584e9                20/09/2021 22:53:49
#
#     declarant_nom declarant_prenom declarant_dateNaissance  \
# 0            ABAD           DAMIEN              05/04/1980
# 1            ABAD           DAMIEN              05/04/1980
# 2            ABAD           DAMIEN              05/04/1980
# 3            ABAD           DAMIEN              05/04/1980
# 4            ABAD           DAMIEN              05/04/1980
# ..            ...              ...                     ...
# 169         ALEDO           Marcel              11/07/1948
# 170         ALEDO           Marcel              11/07/1948
# 171         ALEDO           Marcel              11/07/1948
# 172      ALEMAGNA           Claude              21/09/1957
# 173      ALEMAGNA           Claude              21/09/1957
#
#                                 qualiteDeclarantForPDF  motif_id  \
# 0                                       Député/Ain(01)  CREATION
# 1                                       Député/Ain(01)  CREATION
# 2                                       Député/Ain(01)  CREATION
# 3                                       Député/Ain(01)  CREATION
# 4                                       Député/Ain(01)  CREATION
# ..                                                 ...       ...
# 169   Maire ou adjoint municipal/Clermont-Ferrand (63)  CREATION
# 170   Maire ou adjoint municipal/Clermont-Ferrand (63)  CREATION
# 171   Maire ou adjoint municipal/Clermont-Ferrand (63)  CREATION
# 172  Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
# 173  Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
#
#                   commentaire                           nomSociete evaluation  \
# 0      [Données non publiées]                               ORANGE        877
# 1      [Données non publiées]                   CREDIT AGRICOLE SA       2910
# 2      [Données non publiées]                               AIRBUS       1929
# 3      [Données non publiées]                              L'OREAL       6552
# 4      [Données non publiées]                               ORANGE        877
# ..                        ...                                  ...        ...
# 169  Titre détenu en usufruit  SCI\n        [Données non publiées]      33027
# 170  Titre détenu en usufruit  SCI\n        [Données non publiées]          0
# 171                       NaN  SCI\n        [Données non publiées]          0
# 172                       NaN                                  NaN        NaN
# 173                       NaN                                  NaN        NaN
#
#     remuneration nombreParts actiConseil capitalDetenu
# 0          néant          83         Non           NaN
# 1          néant         341         Non           NaN
# 2          NEANT          20         Non           NaN
# 3          NEANT          20         Non           NaN
# 4          néant          83         Non           NaN
# ..           ...         ...         ...           ...
# 169        Néant        1500         NaN            81
# 170        Néant          99         NaN           100
# 171        Néant        5200         NaN            81
# 172          NaN         NaN         NaN           NaN
# 173          NaN         NaN         NaN           NaN
#
# [174 rows x 14 columns]

# %%
url = "https://raw.githubusercontent.com/louispaulet/hatvp_viz/main/datasets/base/xml_batches/declarations_hatvp_batch_2.xml"
get_stocks_for_url(url)
# Out:
#             declarations_declaration_uuid declarations_declaration_dateDepot  \
# 0    7789d319-d572-43cd-8534-20568f036525                26/09/2021 20:40:19
# 1    2d0e6f00-f37f-4dcd-8b19-75ce0b9348e4                26/09/2021 21:01:41
# 2    868e37c7-94e2-463c-bd9f-d6acb280da1e                25/01/2022 16:28:30
# 3    346c159c-450a-4497-91e1-3573c67f5d17                23/06/2021 22:04:05
# 4    35ac5aa0-03b8-4d3b-a12f-d0451dedcd05                07/09/2021 07:27:30
# ..                                    ...                                ...
# 143  96990322-f9e6-4fff-84ab-365a71275b68                28/09/2021 12:20:00
# 144  96990322-f9e6-4fff-84ab-365a71275b68                28/09/2021 12:20:00
# 145  96990322-f9e6-4fff-84ab-365a71275b68                28/09/2021 12:20:00
# 146  96990322-f9e6-4fff-84ab-365a71275b68                28/09/2021 12:20:00
# 147  1cd96cdb-0307-4329-bff9-1703f8b3dd8a                03/08/2021 17:21:59
#
#     declarant_nom declarant_prenom declarant_dateNaissance  \
# 0        ALEMAGNA           Claude              21/09/1957
# 1        ALEMAGNA           Claude              21/09/1957
# 2        ALEMAGNA           Claude              21/09/1957
# 3         ALEMANI            roger              29/06/1957
# 4         Alemany           Jérôme              19/11/1973
# ..            ...              ...                     ...
# 143        AMSLER      Jean-Daniel              03/04/1946
# 144        AMSLER      Jean-Daniel              03/04/1946
# 145        AMSLER      Jean-Daniel              03/04/1946
# 146        AMSLER      Jean-Daniel              03/04/1946
# 147        Anceau            Alain              12/01/1962
#
#                                 qualiteDeclarantForPDF  motif_id  \
# 0    Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
# 1    Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
# 2    Membre d’EPCI/Dracénie Provence Verdon agglomé...       NaN
# 3                                    Membre d’EPCI/CAE       NaN
# 4    Elu départemental/Loire-Atlantique (44)/Vice-p...       NaN
# ..                                                 ...       ...
# 143  Elu départemental/Val-de-Marne (94)/VICE PRESI...  CREATION
# 144  Elu départemental/Val-de-Marne (94)/VICE PRESI...  CREATION
# 145  Elu départemental/Val-de-Marne (94)/VICE PRESI...  CREATION
# 146  Elu départemental/Val-de-Marne (94)/VICE PRESI...  CREATION
# 147              Elu départemental/Indre-et-Loire (37)       NaN
#
#                    nomSociete evaluation remuneration capitalDetenu  \
# 0                         NaN        NaN          NaN           NaN
# 1                         NaN        NaN          NaN           NaN
# 2                         NaN        NaN          NaN           NaN
# 3                         NaN        NaN          NaN           NaN
# 4                         NaN        NaN          NaN           NaN
# ..                        ...        ...          ...           ...
# 143         TOTAL ENERGIES SE       2224       159.44           NaN
# 144                    ORANGE        157         9.80           NaN
# 145       ACCIMMO PIERRE SCPI      28000          850           NaN
# 146  SOCIETE CENTRALE PREVOIR     690000        26000           NaN
# 147                       NaN        NaN          NaN           NaN
#
#     nombreParts actiConseil                                        commentaire
# 0           NaN         NaN                                                NaN
# 1           NaN         NaN                                                NaN
# 2           NaN         NaN                                                NaN
# 3           NaN         NaN                                                NaN
# 4           NaN         NaN                                                NaN
# ..          ...         ...                                                ...
# 143          61         NaN                                                PEA
# 144          16         NaN                                         PTF Titres
# 145         150         NaN                             Ptf titres BNP paribas
# 146        7500         NaN  7000 TITRES DETENUS EN USUFRUIT et 350 en plei...
# 147         NaN         NaN                                                NaN
#
# [148 rows x 14 columns]

# %% [markdown]
# ## handling the complete 100 batches

# %%
from tqdm.auto import tqdm

df_list = []

# actually 101 batches
for i in tqdm(range(101)):

  url = f"https://raw.githubusercontent.com/louispaulet/hatvp_viz/main/datasets/base/xml_batches/declarations_hatvp_batch_{i+1}.xml"
  df_list.append(get_stocks_for_url(url))
# Out:
#   0%|          | 0/101 [00:00<?, ?it/s]

# %%
# from df list to complete df
complete_df = pd.concat(df_list)
# Out:
#             declarations_declaration_uuid declarations_declaration_dateDepot  \
# 0    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 1    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 2    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 3    4344aaa1-874d-4e6d-9b1a-45f7725b710c                11/07/2022 15:40:13
# 4    fa8d18ec-0db9-4a39-b1f4-caba0c31329b                27/11/2022 18:18:23
# ..                                    ...                                ...
# 102  19140875-1488-43e7-95a7-63d0b7212a19                25/06/2021 13:29:08
# 103  19140875-1488-43e7-95a7-63d0b7212a19                25/06/2021 13:29:08
# 104  19140875-1488-43e7-95a7-63d0b7212a19                25/06/2021 13:29:08
# 105  19140875-1488-43e7-95a7-63d0b7212a19                25/06/2021 13:29:08
# 106  d1129c22-a715-4df6-8c0f-cfc678f1518c                20/08/2022 08:26:16
#
#     declarant_nom declarant_prenom declarant_dateNaissance  \
# 0            ABAD           DAMIEN              05/04/1980
# 1            ABAD           DAMIEN              05/04/1980
# 2            ABAD           DAMIEN              05/04/1980
# 3            ABAD           DAMIEN              05/04/1980
# 4            ABAD           DAMIEN              05/04/1980
# ..            ...              ...                     ...
# 102         zuili          nicolas              08/03/1965
# 103         zuili          nicolas              08/03/1965
# 104         zuili          nicolas              08/03/1965
# 105         zuili          nicolas              08/03/1965
# 106        Zulesi        Jean-Marc              06/06/1988
#
#                     qualiteDeclarantForPDF  motif_id             commentaire  \
# 0                           Député/Ain(01)  CREATION  [Données non publiées]
# 1                           Député/Ain(01)  CREATION  [Données non publiées]
# 2                           Député/Ain(01)  CREATION  [Données non publiées]
# 3                           Député/Ain(01)  CREATION  [Données non publiées]
# 4                           Député/Ain(01)  CREATION  [Données non publiées]
# ..                                     ...       ...                     ...
# 102  Maire ou adjoint municipal/Rouen (76)  CREATION       COMPTE TITRES CDN
# 103  Maire ou adjoint municipal/Rouen (76)  CREATION        COMPTE TITRE CDN
# 104  Maire ou adjoint municipal/Rouen (76)  CREATION       COMPTE TITRES CDN
# 105  Maire ou adjoint municipal/Rouen (76)  CREATION       COMPTE TITRES CDN
# 106            Député/Bouches-du-Rhône(13)       NaN                     NaN
#
#              nomSociete evaluation remuneration nombreParts actiConseil  \
# 0                ORANGE        877        néant          83         Non
# 1    CREDIT AGRICOLE SA       2910        néant         341         Non
# 2                AIRBUS       1929        NEANT          20         Non
# 3               L'OREAL       6552        NEANT          20         Non
# 4                ORANGE        877        néant          83         Non
# ..                  ...        ...          ...         ...         ...
# 102         BNP PARIBAS      10820            0         200         NaN
# 103             RENAULT       7073            0         200         NaN
# 104        SAINT GOBAIN      11238            0         200         NaN
# 105     UNIBAIL RODAMCO       7991            0         100         NaN
# 106                 NaN        NaN          NaN         NaN         NaN
#
#     capitalDetenu nomOrganisationConseil motif_label
# 0             NaN                    NaN         NaN
# 1             NaN                    NaN         NaN
# 2             NaN                    NaN         NaN
# 3             NaN                    NaN         NaN
# 4             NaN                    NaN         NaN
# ..            ...                    ...         ...
# 102           NaN                    NaN         NaN
# 103           NaN                    NaN         NaN
# 104           NaN                    NaN         NaN
# 105           NaN                    NaN         NaN
# 106           NaN                    NaN         NaN
#
# [17068 rows x 16 columns]

# %%
complete_df

# %%
declaration_nb = len(complete_df['declarations_declaration_uuid'].unique())
print(f'Number of declarations in this database: {declaration_nb}')
# Out:
# Number of declarations in this database: 10050

# %%
complete_df.to_csv("/content/drive/MyDrive/AI/HATVP/datasets/hatvp_stocks.csv")
